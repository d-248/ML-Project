# %%
############################################################
# ITERATION FOR HYPERPARAMETER SWEEP
# EXTRAPOLATION SPLIT + FIXED TEST SET
############################################################

# ===================== IMPORT LIBRARIES =====================
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from rdkit import Chem
from rdkit.Chem import AllChem
from itertools import product

# ===================== LOAD DATA =====================
data = pd.read_csv("qm133885_properties.csv")

smiles = data["SMILES"]
y = data["H"].values

# ===================== SMILES → Morgan Fingerprint =====================
def smiles_to_fingerprint(sm):
    mol = Chem.MolFromSmiles(sm)
    if mol is None:
        return np.zeros(1024)

    return np.array(
        AllChem.GetMorganFingerprintAsBitVect(
            mol,
            radius=3,
            nBits=2048
        ),
        dtype=np.float32
    )

# ===============================
# CREATE FINGERPRINT MATRIX
# ===============================
print("Generating fingerprints...")

X = np.array(
    [smiles_to_fingerprint(s) for s in smiles],
    dtype=np.float32
)

print("Fingerprint shape:", X.shape)

# ===============================
# EXTRAPOLATION SPLIT
# ===============================
train_mask = (y >= -460) & (y <= -360)
test_mask = ~train_mask

X_train_full = X[train_mask]
y_train_full = y[train_mask]

X_test_all = X[test_mask]
y_test_all = y[test_mask]

print("\nTrain H range:",
      y_train_full.min(),
      y_train_full.max())

print("Test H range :",
      y_test_all.min(),
      y_test_all.max())

print("Available train samples:",
      len(y_train_full))

print("Available test samples:",
      len(y_test_all))

# ===============================
# FIX TEST SET TO 24,869 SAMPLES
# ===============================
np.random.seed(42)

test_indices = np.random.choice(
    len(X_test_all),
    size=24869,
    replace=False
)

X_test = X_test_all[test_indices]
y_test = y_test_all[test_indices]

print("Fixed Test Samples:",
      len(X_test))

# ===============================
# TRAIN / VALIDATION SPLIT
# ===============================
X_train, X_val, y_train, y_val = train_test_split(
    X_train_full,
    y_train_full,
    test_size=0.20,
    random_state=42
)

print("\nTrain samples:",
      len(y_train))

print("Validation samples:",
      len(y_val))

print("Fixed test samples:",
      len(y_test))

# ===============================
# SCALE DATA
# ===============================
x_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train_scaled = x_scaler.fit_transform(X_train)
X_val_scaled = x_scaler.transform(X_val)
X_test_scaled = x_scaler.transform(X_test)

y_train_scaled = y_scaler.fit_transform(
    y_train.reshape(-1, 1)
).flatten()

y_val_scaled = y_scaler.transform(
    y_val.reshape(-1, 1)
).flatten()

y_test_scaled = y_scaler.transform(
    y_test.reshape(-1, 1)
).flatten()

# ===============================
# MODEL FUNCTION
# ===============================
def create_model(
    neurons1=32,
    neurons2=8,
    neurons3=8,
    lr=0.001,
    activation="relu"
):

    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(2048,)),
        tf.keras.layers.Dense(
            neurons1,
            activation=activation
        ),
        tf.keras.layers.Dense(
            neurons2,
            activation=activation
        ),
        tf.keras.layers.Dense(
            neurons3,
            activation=activation
        ),
        tf.keras.layers.Dense(1)
    ])

    model.compile(
        optimizer=Adam(learning_rate=lr),
        loss="mse",
        metrics=["mae"]
    )

    return model

# ===============================
# HYPERPARAMETER GRID
# ===============================
param_grid = {
    "neurons1": [8,16,32,64,128,256,512,1024],
    "neurons2": [8,16,32,64,128,256,512,1024],
    "neurons3": [8,16,32,64,128,256,512,1024],
    "lr": [0.001],
    "activation": ["relu"]
}

# ===============================
# HYPERPARAMETER SWEEP
# ===============================
results = []

all_params = list(
    product(
        param_grid["neurons1"],
        param_grid["neurons2"],
        param_grid["neurons3"],
        param_grid["lr"],
        param_grid["activation"]
    )
)

print("\nTotal combinations:",
      len(all_params))

for i, (
    neurons1,
    neurons2,
    neurons3,
    lr,
    activation
) in enumerate(all_params, start=1):

    print(
        f"\n[{i}/{len(all_params)}] "
        f"n1={neurons1}, "
        f"n2={neurons2}, "
        f"n3={neurons3}, "
        f"lr={lr}"
    )

    K.clear_session()

    model = create_model(
        neurons1=neurons1,
        neurons2=neurons2,
        neurons3=neurons3,
        lr=lr,
        activation=activation
    )

    history = model.fit(
        X_train_scaled,
        y_train_scaled,
        validation_data=(
            X_val_scaled,
            y_val_scaled
        ),
        epochs=200,
        batch_size=100,
        verbose=0
    )

    # ===============================
    # PREDICTIONS
    # ===============================
    y_train_pred = y_scaler.inverse_transform(
        model.predict(
            X_train_scaled,
            verbose=0
        )
    ).flatten()

    y_val_pred = y_scaler.inverse_transform(
        model.predict(
            X_val_scaled,
            verbose=0
        )
    ).flatten()

    y_test_pred = y_scaler.inverse_transform(
        model.predict(
            X_test_scaled,
            verbose=0
        )
    ).flatten()

    # ===============================
    # R² SCORES
    # ===============================
    r2_train = r2_score(
        y_train,
        y_train_pred
    )

    r2_val = r2_score(
        y_val,
        y_val_pred
    )

    r2_test = r2_score(
        y_test,
        y_test_pred
    )

    results.append({
        "neurons1": neurons1,
        "neurons2": neurons2,
        "neurons3": neurons3,
        "lr": lr,
        "activation": activation,
        "r2_train": r2_train,
        "r2_val": r2_val,
        "r2_test": r2_test
    })

    print(
        f"Train R²={r2_train:.4f} | "
        f"Val R²={r2_val:.4f} | "
        f"Test R²={r2_test:.4f}"
    )

# ===============================
# BEST MODEL (SELECTED BY VAL)
# ===============================
best_result = max(
    results,
    key=lambda x: x["r2_val"]
)

print("\n================ BEST RESULT ================")
print("Best Validation R² :", best_result["r2_val"])
print("Train R²           :", best_result["r2_train"])
print("Test R²            :", best_result["r2_test"])

print("\nBest Parameters")
print("neurons1   :", best_result["neurons1"])
print("neurons2   :", best_result["neurons2"])
print("neurons3   :", best_result["neurons3"])
print("lr         :", best_result["lr"])
print("activation :", best_result["activation"])
# Out:
# Generating fingerprints...
# Fingerprint shape: (133885, 2048)
#
# Train H range: -459.185274 -360.000294
# Test H range : -714.559209 -40.475117
# Available train samples: 109016
# Available test samples: 24869
# Fixed Test Samples: 24869
#
# Train samples: 87212
# Validation samples: 21804
# Fixed test samples: 24869
#
# Total combinations: 512
#
# [1/512] n1=8, n2=8, n3=8, lr=0.001
# Train R²=0.8501 | Val R²=0.5844 | Test R²=0.5953
#
# [2/512] n1=8, n2=8, n3=16, lr=0.001
# Train R²=0.8772 | Val R²=0.5683 | Test R²=0.5656
#
# [3/512] n1=8, n2=8, n3=32, lr=0.001
# Train R²=0.8760 | Val R²=0.5771 | Test R²=0.5807
#
# [4/512] n1=8, n2=8, n3=64, lr=0.001
# Train R²=0.8798 | Val R²=0.5721 | Test R²=0.5739
#
# [5/512] n1=8, n2=8, n3=128, lr=0.001
# Train R²=0.8838 | Val R²=0.5764 | Test R²=0.5757
#
# [6/512] n1=8, n2=8, n3=256, lr=0.001
# Train R²=0.8844 | Val R²=0.5655 | Test R²=0.5828
#
# [7/512] n1=8, n2=8, n3=512, lr=0.001
# Train R²=0.8899 | Val R²=0.5779 | Test R²=0.5616
#
# [8/512] n1=8, n2=8, n3=1024, lr=0.001
# Train R²=0.8878 | Val R²=0.5761 | Test R²=0.5623
#
# [9/512] n1=8, n2=16, n3=8, lr=0.001
# Train R²=0.8736 | Val R²=0.5871 | Test R²=0.5785
#
# [10/512] n1=8, n2=16, n3=16, lr=0.001
# Train R²=0.8752 | Val R²=0.5877 | Test R²=0.5709
#
# [11/512] n1=8, n2=16, n3=32, lr=0.001
# Train R²=0.8860 | Val R²=0.5958 | Test R²=0.5649
#
# [12/512] n1=8, n2=16, n3=64, lr=0.001
# Train R²=0.8926 | Val R²=0.5519 | Test R²=0.5483
#
# [13/512] n1=8, n2=16, n3=128, lr=0.001
# Train R²=0.8861 | Val R²=0.5617 | Test R²=0.5646
#
# [14/512] n1=8, n2=16, n3=256, lr=0.001
# Train R²=0.8873 | Val R²=0.5516 | Test R²=0.5683
#
# [15/512] n1=8, n2=16, n3=512, lr=0.001
# Train R²=0.8934 | Val R²=0.5743 | Test R²=0.5753
#
# [16/512] n1=8, n2=16, n3=1024, lr=0.001
# Train R²=0.8893 | Val R²=0.5589 | Test R²=0.5730
#
# [17/512] n1=8, n2=32, n3=8, lr=0.001
# Train R²=0.8835 | Val R²=0.5898 | Test R²=0.5750
#
# [18/512] n1=8, n2=32, n3=16, lr=0.001
# Train R²=0.8826 | Val R²=0.5638 | Test R²=0.5752
#
# [19/512] n1=8, n2=32, n3=32, lr=0.001
# Train R²=0.8859 | Val R²=0.5632 | Test R²=0.5683
#
# [20/512] n1=8, n2=32, n3=64, lr=0.001
# Train R²=0.8902 | Val R²=0.5645 | Test R²=0.5743
#
# [21/512] n1=8, n2=32, n3=128, lr=0.001
# Train R²=0.8945 | Val R²=0.5368 | Test R²=0.5679
#
# [22/512] n1=8, n2=32, n3=256, lr=0.001
# Train R²=0.8991 | Val R²=0.5729 | Test R²=0.5747
#
# [23/512] n1=8, n2=32, n3=512, lr=0.001
# Train R²=0.8978 | Val R²=0.5521 | Test R²=0.5591
#
# [24/512] n1=8, n2=32, n3=1024, lr=0.001
# Train R²=0.9001 | Val R²=0.5638 | Test R²=0.5571
#
# [25/512] n1=8, n2=64, n3=8, lr=0.001
# Train R²=0.8884 | Val R²=0.5590 | Test R²=0.5669
#
# [26/512] n1=8, n2=64, n3=16, lr=0.001
# Train R²=0.8927 | Val R²=0.5574 | Test R²=0.5996
#
# [27/512] n1=8, n2=64, n3=32, lr=0.001
# Train R²=0.8969 | Val R²=0.5617 | Test R²=0.5644
#
# [28/512] n1=8, n2=64, n3=64, lr=0.001
# Train R²=0.8953 | Val R²=0.5446 | Test R²=0.5589
#
# [29/512] n1=8, n2=64, n3=128, lr=0.001
# Train R²=0.9013 | Val R²=0.5563 | Test R²=0.5433
#
# [30/512] n1=8, n2=64, n3=256, lr=0.001
# Train R²=0.9019 | Val R²=0.5487 | Test R²=0.5699
#
# [31/512] n1=8, n2=64, n3=512, lr=0.001
# Train R²=0.9021 | Val R²=0.5577 | Test R²=0.5599
#
# [32/512] n1=8, n2=64, n3=1024, lr=0.001
# Train R²=0.9030 | Val R²=0.5466 | Test R²=0.5600
#
# [33/512] n1=8, n2=128, n3=8, lr=0.001
# Train R²=0.8906 | Val R²=0.5530 | Test R²=0.5472
#
# [34/512] n1=8, n2=128, n3=16, lr=0.001
# Train R²=0.8940 | Val R²=0.5531 | Test R²=0.5793
#
# [35/512] n1=8, n2=128, n3=32, lr=0.001
# Train R²=0.8993 | Val R²=0.5521 | Test R²=0.5623
#
# [36/512] n1=8, n2=128, n3=64, lr=0.001
# Train R²=0.9017 | Val R²=0.5496 | Test R²=0.5967
#
# [37/512] n1=8, n2=128, n3=128, lr=0.001
# Train R²=0.9016 | Val R²=0.5492 | Test R²=0.5696
#
# [38/512] n1=8, n2=128, n3=256, lr=0.001
# Train R²=0.9084 | Val R²=0.5501 | Test R²=0.5674
#
# [39/512] n1=8, n2=128, n3=512, lr=0.001
# Train R²=0.9115 | Val R²=0.5607 | Test R²=0.5669
#
# [40/512] n1=8, n2=128, n3=1024, lr=0.001
# Train R²=0.9065 | Val R²=0.5522 | Test R²=0.5728
#
# [41/512] n1=8, n2=256, n3=8, lr=0.001
# Train R²=0.8990 | Val R²=0.5671 | Test R²=0.5711
#
# [42/512] n1=8, n2=256, n3=16, lr=0.001
# Train R²=0.8987 | Val R²=0.5880 | Test R²=0.5598
#
# [43/512] n1=8, n2=256, n3=32, lr=0.001
# Train R²=0.8990 | Val R²=0.5446 | Test R²=0.5552
#
# [44/512] n1=8, n2=256, n3=64, lr=0.001
# Train R²=0.9035 | Val R²=0.5410 | Test R²=0.5744
#
# [45/512] n1=8, n2=256, n3=128, lr=0.001
# Train R²=0.9080 | Val R²=0.5458 | Test R²=0.5671
#
# [46/512] n1=8, n2=256, n3=256, lr=0.001
# Train R²=0.9079 | Val R²=0.5522 | Test R²=0.5639
#
# [47/512] n1=8, n2=256, n3=512, lr=0.001
# Train R²=0.9077 | Val R²=0.5626 | Test R²=0.5692
#
# [48/512] n1=8, n2=256, n3=1024, lr=0.001
# Train R²=0.9092 | Val R²=0.5503 | Test R²=0.5489
#
# [49/512] n1=8, n2=512, n3=8, lr=0.001
# Train R²=0.8980 | Val R²=0.5732 | Test R²=0.5444
#
# [50/512] n1=8, n2=512, n3=16, lr=0.001
# Train R²=0.9040 | Val R²=0.5583 | Test R²=0.5744
#
# [51/512] n1=8, n2=512, n3=32, lr=0.001
# Train R²=0.9024 | Val R²=0.5349 | Test R²=0.5486
#
# [52/512] n1=8, n2=512, n3=64, lr=0.001
# Train R²=0.9035 | Val R²=0.5620 | Test R²=0.5681
#
# [53/512] n1=8, n2=512, n3=128, lr=0.001
# Train R²=0.8979 | Val R²=0.5291 | Test R²=0.5550
#
# [54/512] n1=8, n2=512, n3=256, lr=0.001
# Train R²=0.9006 | Val R²=0.5264 | Test R²=0.5487
#
# [55/512] n1=8, n2=512, n3=512, lr=0.001
# Train R²=0.9076 | Val R²=0.5506 | Test R²=0.5598
#
# [56/512] n1=8, n2=512, n3=1024, lr=0.001
# Train R²=0.9082 | Val R²=0.5680 | Test R²=0.5486
#
# [57/512] n1=8, n2=1024, n3=8, lr=0.001
# Train R²=0.8926 | Val R²=0.5548 | Test R²=0.5789
#
# [58/512] n1=8, n2=1024, n3=16, lr=0.001
# Train R²=0.8965 | Val R²=0.5508 | Test R²=0.5650
#
# [59/512] n1=8, n2=1024, n3=32, lr=0.001
# Train R²=0.9020 | Val R²=0.5628 | Test R²=0.5807
#
# [60/512] n1=8, n2=1024, n3=64, lr=0.001
# Train R²=0.9035 | Val R²=0.5614 | Test R²=0.5768
#
# [61/512] n1=8, n2=1024, n3=128, lr=0.001
# Train R²=0.9164 | Val R²=0.5647 | Test R²=0.5073
#
# [62/512] n1=8, n2=1024, n3=256, lr=0.001
# Train R²=0.9067 | Val R²=0.5515 | Test R²=0.5526
#
# [63/512] n1=8, n2=1024, n3=512, lr=0.001
# Train R²=0.9079 | Val R²=0.5519 | Test R²=0.5587
#
# [64/512] n1=8, n2=1024, n3=1024, lr=0.001
# Train R²=0.9056 | Val R²=0.5439 | Test R²=0.5617
#
# [65/512] n1=16, n2=8, n3=8, lr=0.001
# Train R²=0.9234 | Val R²=0.5022 | Test R²=0.6061
#
# [66/512] n1=16, n2=8, n3=16, lr=0.001
# Train R²=0.9325 | Val R²=0.5179 | Test R²=0.6270
#
# [67/512] n1=16, n2=8, n3=32, lr=0.001
# Train R²=0.9440 | Val R²=0.5490 | Test R²=0.5883
#
# [68/512] n1=16, n2=8, n3=64, lr=0.001
# Train R²=0.9365 | Val R²=0.5103 | Test R²=0.5778
#
# [69/512] n1=16, n2=8, n3=128, lr=0.001
# Train R²=0.9423 | Val R²=0.5201 | Test R²=0.5844
#
# [70/512] n1=16, n2=8, n3=256, lr=0.001
# Train R²=0.9444 | Val R²=0.5352 | Test R²=0.5736
#
# [71/512] n1=16, n2=8, n3=512, lr=0.001
# Train R²=0.9507 | Val R²=0.5324 | Test R²=0.5811
#
# [72/512] n1=16, n2=8, n3=1024, lr=0.001
# Train R²=0.9497 | Val R²=0.5279 | Test R²=0.5823
#
# [73/512] n1=16, n2=16, n3=8, lr=0.001
# Train R²=0.9387 | Val R²=0.5247 | Test R²=0.5991
#
# [74/512] n1=16, n2=16, n3=16, lr=0.001
# Train R²=0.9427 | Val R²=0.5332 | Test R²=0.5836
#
# [75/512] n1=16, n2=16, n3=32, lr=0.001
# Train R²=0.9432 | Val R²=0.5289 | Test R²=0.6213
#
# [76/512] n1=16, n2=16, n3=64, lr=0.001
# Train R²=0.9488 | Val R²=0.5296 | Test R²=0.5741
#
# [77/512] n1=16, n2=16, n3=128, lr=0.001
# Train R²=0.9461 | Val R²=0.5220 | Test R²=0.6062
#
# [78/512] n1=16, n2=16, n3=256, lr=0.001
# Train R²=0.9530 | Val R²=0.5321 | Test R²=0.5877
#
# [79/512] n1=16, n2=16, n3=512, lr=0.001
# Train R²=0.9522 | Val R²=0.5360 | Test R²=0.5898
#
# [80/512] n1=16, n2=16, n3=1024, lr=0.001
# Train R²=0.9496 | Val R²=0.5325 | Test R²=0.5734
#
# [81/512] n1=16, n2=32, n3=8, lr=0.001
# Train R²=0.9390 | Val R²=0.5046 | Test R²=0.6176
#
# [82/512] n1=16, n2=32, n3=16, lr=0.001
# Train R²=0.9418 | Val R²=0.4671 | Test R²=0.6242
#
# [83/512] n1=16, n2=32, n3=32, lr=0.001
# Train R²=0.9472 | Val R²=0.5125 | Test R²=0.6149
#
# [84/512] n1=16, n2=32, n3=64, lr=0.001
# Train R²=0.9510 | Val R²=0.5173 | Test R²=0.5951
#
# [85/512] n1=16, n2=32, n3=128, lr=0.001
# Train R²=0.9583 | Val R²=0.5438 | Test R²=0.5962
#
# [86/512] n1=16, n2=32, n3=256, lr=0.001
# Train R²=0.9583 | Val R²=0.5466 | Test R²=0.5639
#
# [87/512] n1=16, n2=32, n3=512, lr=0.001
# Train R²=0.9592 | Val R²=0.5587 | Test R²=0.5739
#
# [88/512] n1=16, n2=32, n3=1024, lr=0.001
# Train R²=0.9616 | Val R²=0.5427 | Test R²=0.5898
#
# [89/512] n1=16, n2=64, n3=8, lr=0.001
# Train R²=0.9475 | Val R²=0.5065 | Test R²=0.6201
#
# [90/512] n1=16, n2=64, n3=16, lr=0.001
# Train R²=0.9512 | Val R²=0.5322 | Test R²=0.5865
#
# [91/512] n1=16, n2=64, n3=32, lr=0.001
# Train R²=0.9538 | Val R²=0.5330 | Test R²=0.5898
#
# [92/512] n1=16, n2=64, n3=64, lr=0.001
# Train R²=0.9594 | Val R²=0.5107 | Test R²=0.6184
#
# [93/512] n1=16, n2=64, n3=128, lr=0.001
# Train R²=0.9615 | Val R²=0.5288 | Test R²=0.5848
#
# [94/512] n1=16, n2=64, n3=256, lr=0.001
# Train R²=0.9660 | Val R²=0.5377 | Test R²=0.5901
#
# [95/512] n1=16, n2=64, n3=512, lr=0.001
# Train R²=0.9657 | Val R²=0.5181 | Test R²=0.6020
#
# [96/512] n1=16, n2=64, n3=1024, lr=0.001
# Train R²=0.9673 | Val R²=0.5349 | Test R²=0.6004
#
# [97/512] n1=16, n2=128, n3=8, lr=0.001
# Train R²=0.9545 | Val R²=0.5201 | Test R²=0.6062
#
# [98/512] n1=16, n2=128, n3=16, lr=0.001
# Train R²=0.9581 | Val R²=0.5436 | Test R²=0.6155
#
# [99/512] n1=16, n2=128, n3=32, lr=0.001
# Train R²=0.9629 | Val R²=0.5310 | Test R²=0.6070
#
# [100/512] n1=16, n2=128, n3=64, lr=0.001
# Train R²=0.9647 | Val R²=0.5304 | Test R²=0.5948
#
# [101/512] n1=16, n2=128, n3=128, lr=0.001
# Train R²=0.9670 | Val R²=0.5375 | Test R²=0.5937
#
# [102/512] n1=16, n2=128, n3=256, lr=0.001
# Train R²=0.9718 | Val R²=0.5424 | Test R²=0.5685
#
# [103/512] n1=16, n2=128, n3=512, lr=0.001
# Train R²=0.9718 | Val R²=0.5494 | Test R²=0.5975
#
# [104/512] n1=16, n2=128, n3=1024, lr=0.001
# Train R²=0.9747 | Val R²=0.5477 | Test R²=0.5968
#
# [105/512] n1=16, n2=256, n3=8, lr=0.001
# Train R²=0.9624 | Val R²=0.5258 | Test R²=0.6107
#
# [106/512] n1=16, n2=256, n3=16, lr=0.001
# Train R²=0.9620 | Val R²=0.5273 | Test R²=0.6021
#
# [107/512] n1=16, n2=256, n3=32, lr=0.001
# Train R²=0.9674 | Val R²=0.5482 | Test R²=0.5852
#
# [108/512] n1=16, n2=256, n3=64, lr=0.001
# Train R²=0.9723 | Val R²=0.5438 | Test R²=0.5729
#
# [109/512] n1=16, n2=256, n3=128, lr=0.001
# Train R²=0.9686 | Val R²=0.5357 | Test R²=0.5930
#
# [110/512] n1=16, n2=256, n3=256, lr=0.001
# Train R²=0.9750 | Val R²=0.5500 | Test R²=0.5808
#
# [111/512] n1=16, n2=256, n3=512, lr=0.001
# Train R²=0.9772 | Val R²=0.5506 | Test R²=0.5979
#
# [112/512] n1=16, n2=256, n3=1024, lr=0.001
# Train R²=0.9752 | Val R²=0.5600 | Test R²=0.5693
#
# [113/512] n1=16, n2=512, n3=8, lr=0.001
# Train R²=0.9694 | Val R²=0.5515 | Test R²=0.5556
#
# [114/512] n1=16, n2=512, n3=16, lr=0.001
# Train R²=0.9670 | Val R²=0.5366 | Test R²=0.5686
#
# [115/512] n1=16, n2=512, n3=32, lr=0.001
# Train R²=0.9743 | Val R²=0.5576 | Test R²=0.5853
#
# [116/512] n1=16, n2=512, n3=64, lr=0.001
# Train R²=0.9751 | Val R²=0.5533 | Test R²=0.5711
#
# [117/512] n1=16, n2=512, n3=128, lr=0.001
# Train R²=0.9777 | Val R²=0.5661 | Test R²=0.5773
#
# [118/512] n1=16, n2=512, n3=256, lr=0.001
# Train R²=0.9798 | Val R²=0.5784 | Test R²=0.5654
#
# [119/512] n1=16, n2=512, n3=512, lr=0.001
# Train R²=0.9806 | Val R²=0.5659 | Test R²=0.5645
#
# [120/512] n1=16, n2=512, n3=1024, lr=0.001
# Train R²=0.9805 | Val R²=0.5203 | Test R²=0.5991
#
# [121/512] n1=16, n2=1024, n3=8, lr=0.001
# Train R²=0.9697 | Val R²=0.5403 | Test R²=0.6086
#
# [122/512] n1=16, n2=1024, n3=16, lr=0.001
# Train R²=0.9717 | Val R²=0.5371 | Test R²=0.5818
#
# [123/512] n1=16, n2=1024, n3=32, lr=0.001
# Train R²=0.9745 | Val R²=0.5489 | Test R²=0.5739
#
# [124/512] n1=16, n2=1024, n3=64, lr=0.001
# Train R²=0.9751 | Val R²=0.5588 | Test R²=0.5746
#
# [125/512] n1=16, n2=1024, n3=128, lr=0.001
# Train R²=0.9745 | Val R²=0.5589 | Test R²=0.5836
#
# [126/512] n1=16, n2=1024, n3=256, lr=0.001
# Train R²=0.9789 | Val R²=0.5323 | Test R²=0.5776
#
# [127/512] n1=16, n2=1024, n3=512, lr=0.001
# Train R²=0.9808 | Val R²=0.5652 | Test R²=0.5887
#
# [128/512] n1=16, n2=1024, n3=1024, lr=0.001
# Train R²=0.9824 | Val R²=0.5768 | Test R²=0.6009
#
# [129/512] n1=32, n2=8, n3=8, lr=0.001
# Train R²=0.9779 | Val R²=0.4499 | Test R²=0.6199
#
# [130/512] n1=32, n2=8, n3=16, lr=0.001
# Train R²=0.9829 | Val R²=0.5559 | Test R²=0.6343
#
# [131/512] n1=32, n2=8, n3=32, lr=0.001
# Train R²=0.9840 | Val R²=0.5301 | Test R²=0.5775
#
# [132/512] n1=32, n2=8, n3=64, lr=0.001
# Train R²=0.9866 | Val R²=0.5251 | Test R²=0.5936
#
# [133/512] n1=32, n2=8, n3=128, lr=0.001
# Train R²=0.9850 | Val R²=0.5513 | Test R²=0.6039
#
# [134/512] n1=32, n2=8, n3=256, lr=0.001
# Train R²=0.9845 | Val R²=0.5156 | Test R²=0.6113
#
# [135/512] n1=32, n2=8, n3=512, lr=0.001
# Train R²=0.9883 | Val R²=0.5791 | Test R²=0.5632
#
# [136/512] n1=32, n2=8, n3=1024, lr=0.001
# Train R²=0.9865 | Val R²=0.5569 | Test R²=0.5821
#
# [137/512] n1=32, n2=16, n3=8, lr=0.001
